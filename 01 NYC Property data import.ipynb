# %% [markdown]
# # Predicting NYC apartment's value with open data
#
# According to real estate brokers in NYC, there are a variety of factors they consider to determine the value of your apartment, not limited to
#
# 1. Recent sales in your building / Neighbourhood
# 2. Square footage
# 3. Renovation status
# 4. View, close to subway, # of bedrooms etc.
#
# Unfortunately this data, especially apt sq footage, is not easily available for non REBNY members.
#
# In this notebook, I will explore an alternative approach to price Manhattan apartments.

# %%
import numpy as np
import pandas as pd

from datascience import *

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

import locale
import os
import xlrd as xlrd

# %% [markdown]
# ## Import data
#
# Source
# 1. [Annualized Sales Data](https://www1.nyc.gov/site/finance/taxes/property-annualized-sales-update.page)
# 2. [Rolling Sale data](https://www1.nyc.gov/site/finance/taxes/property-rolling-sales-data.page)

# %%
# Constants
raw_directory = "data/raw/"
csv_directory = "data/csv/"

# Retrieve current working directory (`cwd`)
cwd = os.getcwd()

# List data files and directories in current directory
excel_files = os.listdir(raw_directory)

# Select only tje xls files
excel_files = [k for k in excel_files if '.xls' in k]

# %%
excel_files[:len(excel_files)]
# Out:
# ['2015_manhattan.xls',
#  '2011_manhattan.xls',
#  '2016_manhattan.xls',
#  '2012_manhattan.xls',
#  'rollingsales_manhattan.xls',
#  'sales_manhattan_03.xls',
#  'sales_manhattan_06.xls',
#  'sales_manhattan_04.xls',
#  'sales_2007_manhattan.xls',
#  'sales_manhattan_05.xls',
#  '2009_manhattan.xls',
#  '2013_manhattan.xls',
#  '2017_manhattan.xls',
#  'sales_2008_manhattan.xls',
#  '2010_manhattan.xls',
#  '2014_manhattan.xls']

# %% [markdown]
# Unfortunately not all files are formatted the same was. Some have the header in row 4, others in row 5. We can check by making sure 'BOROUGH' is the first column in the imported dataset

# %%
# Create an data store
all_sales_data = pd.DataFrame()

# Load individual excel files. 
for excel_file in excel_files:
    print(excel_file)
    
    # Read excel, Note the headers could in row 4 or row 5 (index=3 or 4). 
    yearly_sales_data = pd.read_excel(raw_directory+excel_file, header=3, encoding='sys.getfilesystemencoding()')
   
    # Check if the first column is "BOROUGH"
    if not yearly_sales_data.columns[0].startswith('BOROUGH'):
        # Otherwise the data starts from row 5.
         yearly_sales_data = pd.read_excel(raw_directory+excel_file, header=4, encoding='sys.getfilesystemencoding()')
    
    print(yearly_sales_data.shape)
    
    yearly_sales_data.rename(columns=lambda x: x.strip(), inplace=True)
    
    all_sales_data = all_sales_data.append(yearly_sales_data)
    
    print(all_sales_data.shape)
# Out:
# 2015_manhattan.xls
# (24989, 21)
# (24989, 21)
# 2011_manhattan.xls
# (21500, 21)
# (46489, 21)
# 2016_manhattan.xls
# (21241, 21)
# (67730, 21)
# 2012_manhattan.xls
# (26258, 21)
# (93988, 21)
# rollingsales_manhattan.xls
# (16828, 21)
# (110816, 21)
# sales_manhattan_03.xls
# (22210, 21)
# (133026, 21)
# sales_manhattan_06.xls
# (26352, 21)
# (159378, 21)
# sales_manhattan_04.xls
# (25894, 21)
# (185272, 21)
# sales_2007_manhattan.xls
# (28439, 21)
# (213711, 21)
# sales_manhattan_05.xls
# (26388, 21)
# (240099, 21)
# 2009_manhattan.xls
# (19166, 21)
# (259265, 21)
# 2013_manhattan.xls
# (26715, 21)
# (285980, 21)
# 2017_manhattan.xls
# (18642, 21)
# (304622, 23)
# sales_2008_manhattan.xls
# /Users/somya/Library/Python/3.7/lib/python/site-packages/pandas/core/frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
# (25994, 21)
# (330616, 23)
# 2010_manhattan.xls
# (17296, 21)
# (347912, 23)
# 2014_manhattan.xls
# (24524, 21)
# (372436, 23)

# %% [markdown]
# Spot check to verify data

# %%
all_sales_data.sample(10)
# Out:
#                                          ADDRESS APARTMENT NUMBER  BLOCK  \
# 935    305 WEST 18 STREET                            1G              742
# 21727  170 EAST 87TH   STREET                        W18H           1515
# 17255  459 WASHINGTON STREET                         7N              595
# 22876  37 WEST 89TH   STREET                                        1203
# 18227  944 FIFTH AVENUE, 4                                          1390
# 1455   415 WEST 57TH STREET, 3C                                     1067
# 21265  300 EAST 85TH STREET, 201                                    1547
# 10294  200 WEST 56TH   STREET                                       1027
# 13778  200 WEST 56TH   STREET                                       1027
# 4785   245 E 24TH STREET, 15G                                        905
#
#        BOROUGH BUILDING CLASS AS OF FINAL ROLL 17/18  \
# 935          1                                   NaN
# 21727        1                                   NaN
# 17255        1                                   NaN
# 22876        1                                   NaN
# 18227        1                                   NaN
# 1455         1                                   NaN
# 21265        1                                   NaN
# 10294        1                                   NaN
# 13778        1                                   NaN
# 4785         1                                   NaN
#
#       BUILDING CLASS AT PRESENT BUILDING CLASS AT TIME OF SALE  \
# 935                          R4                             R4
# 21727                        R4                             R4
# 17255                        R4                             R4
# 22876                        C5                             C5
# 18227                        D4                             D4
# 1455                         D4                             D4
# 21265                        D4                             D4
# 10294                        RH                             RH
# 13778                        RH                             RH
# 4785                         D4                             D4
#
#                             BUILDING CLASS CATEGORY  COMMERCIAL UNITS  \
# 935    13  CONDOS - ELEVATOR APARTMENTS                             0
# 21727  13  CONDOS - ELEVATOR APARTMENTS                             0
# 17255  13  CONDOS - ELEVATOR APARTMENTS                             0
# 22876  07  RENTALS - WALKUP APARTMENTS                              0
# 18227  10  COOPS - ELEVATOR APARTMENTS                              0
# 1455   10  COOPS - ELEVATOR APARTMENTS                              0
# 21265  10  COOPS - ELEVATOR APARTMENTS                              0
# 10294                                                               0
# 13778  45  CONDO HOTELS                                             0
# 4785   10  COOPS - ELEVATOR APARTMENTS                              0
#
#       EASE-MENT    ...                  NEIGHBORHOOD  RESIDENTIAL UNITS  \
# 935                ...     CHELSEA                                    1
# 21727              ...     UPPER EAST SIDE (79-96)                    1
# 17255              ...     SOHO                                       1
# 22876              ...     UPPER WEST SIDE (79-96)                   10
# 18227              ...     UPPER EAST SIDE (59-79)                    0
# 1455               ...     CLINTON                                    0
# 21265              ...     UPPER EAST SIDE (79-96)                    0
# 10294              ...     MIDTOWN WEST                               0
# 13778              ...     MIDTOWN WEST                               0
# 4785               ...     GRAMERCY                                   0
#
#        SALE DATE SALE PRICE  TAX CLASS AS OF FINAL ROLL 17/18  \
# 935   2006-10-04     400000                               NaN
# 21727 2012-10-24    1200000                               NaN
# 17255 2006-04-03    2000000                               NaN
# 22876 2015-06-15    5200000                               NaN
# 18227 2006-12-04    7500000                               NaN
# 1455  2004-05-14     250000                               NaN
# 21265 2012-11-08     510000                               NaN
# 10294 2012-12-03          0                               NaN
# 13778 2013-12-30        100                               NaN
# 4785  2008-11-03          0                               NaN
#
#       TAX CLASS AT PRESENT  TAX CLASS AT TIME OF SALE TOTAL UNITS YEAR BUILT  \
# 935                      2                          2           1       1950
# 21727                    2                          2           1          0
# 17255                    2                          2           1          0
# 22876                   2B                          2          10       1930
# 18227                    2                          2           0       1925
# 1455                     2                          2           0       1900
# 21265                    2                          2           0       1987
# 10294                    4                          4           1          0
# 13778                    4                          4           1          0
# 4785                     2                          2           0       1963
#
#        ZIP CODE
# 935       10011
# 21727     10128
# 17255     10013
# 22876     10024
# 18227     10021
# 1455      10019
# 21265     10028
# 10294     10019
# 13778     10019
# 4785      10010
#
# [10 rows x 23 columns]

# %%
# Check for duplicate entries
sum(all_sales_data.duplicated(all_sales_data.columns))
# Out:
# 16137

# %%
#Delete the duplicates and check that it worked
all_sales_data = all_sales_data.drop_duplicates(all_sales_data.columns, keep='last')
sum(all_sales_data.duplicated(all_sales_data.columns))
# Out:
# 0

# %% [markdown]
# Save the data as a CSV for further clean up and analyis. See Step 2.

# %%
# save to csv
all_sales_data.to_csv(csv_directory+"manhattan.csv")
